# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Albert\\Desktop\\Dataminingfile\\test.csv')

# %%
new_df = df.describe(include='all')

# %%
new_df.to_csv('DataQualityReport.csv')

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
cont_df = df.describe()

# %%
cont_df.to_csv('continuousDataQualityReport.csv')

# %%
df.mode()
# Out:
#     age     job  marital          education default housing loan   contact  \
# 0  31.0  admin.  married  university.degree      no     yes   no  cellular
# 1   NaN     NaN      NaN                NaN     NaN     NaN  NaN       NaN
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         thu  ...       1.0  999.0       0.0  nonexistent          1.4
# 1   NaN         NaN  ...       NaN    NaN       NaN          NaN          NaN
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0          93.994          -36.4      4.857       5228.1   no
# 1             NaN            NaN        NaN          NaN  NaN
#
# [2 rows x 21 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
df['job'].mode()
# Out:
# 0    admin.
# dtype: object

# %%
new_df = df.groupby(['marital']).count().sort_values(by=['default'], ascending=False)
new_df
# Out:
#             age    job  education  default  housing   loan  contact  month  \
# marital
# married   24928  24928      24928    24928    24928  24928    24928  24928
# single    11568  11568      11568    11568    11568  11568    11568  11568
# divorced   4612   4612       4612     4612     4612   4612     4612   4612
# unknown      80     80         80       80       80     80       80     80
#
#           day_of_week  duration  campaign  pdays  previous  poutcome  \
# marital
# married         24928     24928     24928  24928     24928     24928
# single          11568     11568     11568  11568     11568     11568
# divorced         4612      4612      4612   4612      4612      4612
# unknown            80        80        80     80        80        80
#
#           emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# marital
# married          24928           24928          24928      24928        24928
# ...

# %%
new_df.iloc[0,0]
# Out:
# 24928

# %%
len(new_df)
# Out:
# 4

# %%
len(df)
# Out:
# 41188

# %%
firstPercent = ((new_df.iloc[0,0]) / (len(df)) * 100)

# %%
new_df.iloc[1,0]
# Out:
# 11568

# %%
len(new_df)
# Out:
# 4

# %%
print(((new_df.iloc[1,0]) / (len(df)) * 100),"%")
# Out:
# 28.085850247644945 %

# %%
new_table['1st mode Frequency'] = new_df.iloc[0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-da9b67b14e46> in <module>
# ----> 1 new_table['1st mode Frequency'] = new_df.iloc[0,0]
#
# NameError: name 'new_table' is not defined

# %%
maritaltable = pd.DataFrame()

# %%
maritaltable['2st mode Frequency'] = new_df.iloc[1,0]

# %%
maritaltable['1st mode'] = df['marital'].mode()

# %%
maritaltable['category'] = df.columns[2]

# %% [raw]
# maritaltable

# %%
maritaltable
# Out:
#    1st mode Frequency 1st mode category
# 0               24928  married  marital
